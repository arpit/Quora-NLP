# %% [markdown]
# # Exploring Quora data
#
# We are looking to investigate if Forum conversations can be used to extract structured data for XA

# %%
import pandas as pd
import numpy as np
import spacy
import en_core_web_sm
import textacy
import nltk

from spacy.lang.en.stop_words import STOP_WORDS
from nltk.stem.porter import *

nlp = en_core_web_sm.load()

# %%
rows = pd.read_csv("data/quora.csv")

# %%
data = rows.head(1000)

# %%
stemmer = PorterStemmer()

def recognizePOS(parsed, POS) :
    words = []
    for token in parsed :
        if token.pos_ == POS :
            word = token.orth_
            words.append(word)
    return words


def extractEntities(text):   
    text = text.lower()
    
    doc = nlp(text)
    
    token_list = []
    for token in doc:
        token_list.append(token.lemma_)
        
    filtered_sentence =[] 

    for word in token_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False:
            filtered_sentence.append(word) 

    
    svos = textacy.extract.subject_verb_object_triples(doc)
    doc = nlp(" ".join(filtered_sentence))
    return pd.Series(data=[text, [chunk.text for chunk in doc.noun_chunks], 
                           recognizePOS(doc, "NOUN"),
                           recognizePOS(doc, "VERB"),
                           recognizePOS(doc, "ADJ"),
                           [svo for svo in svos]
                           ]
                    )

# %%
nRows = data.apply(lambda row : extractEntities(row["question1"]),axis=1)

# %%
nRows = nRows.rename(columns={0: "text", 1: "noun chunks", 2: "nouns", 3: "verbs", 4: "adjs", 5: "Sub/Verb/Obj"})
nRows.head(20)
# Out:
#                                                  text  \
# 0   what is the step by step guide to invest in sh...
# 1   what is the story of kohinoor (koh-i-noor) dia...
# 2   how can i increase the speed of my internet co...
# 3   why am i mentally very lonely? how can i solve...
# 4   which one dissolve in water quikly sugar, salt...
# 5   astrology: i am a capricorn sun cap moon and c...
# 6                                 should i buy tiago?
# 7                      how can i be a good geologist?
# 8                     when do you use シ instead of し?
# 9   motorola (company): can i hack my charter moto...
# 10  method to find separation of slits using fresn...
# 11        how do i read and find my youtube comments?
# 12               what can make physics easy to learn?
# 13        what was your first sexual experience like?
# 14  what are the laws to change your status from a...
# 15  what would a trump presidency mean for current...
# 16                       what does manipulation mean?
# 17  why do girls want to be friends with the guy t...
# 18  why are so many quora users posting questions ...
# 19  which is the best digital marketing institutio...
#
#                                           noun chunks  \
# 0               [step step guide, share market india]
# 1                            [koh - - noor ) diamond]
# 2             [speed -PRON- internet connection, vpn]
# 3                                                  []
# 4   [water quikly sugar, salt , methane carbon di ...
# 5                                 [capricorn sun cap]
# 6                                                  []
# 7                                    [good geologist]
# 8                                              [シ, し]
# 9                                 [motorola, company]
# 10              [method, separation, fresnel biprism]
# 11                      [find -PRON- youtube comment]
# 12                                                 []
# 13                         [-PRON- sexual experience]
# 14  [law, -PRON- status student visa green card, i...
# 15  [trump presidency, current international maste...
# 16                                     [manipulation]
# 17                                 [girl, friend guy]
# 18                 [quora user post question, google]
# 19                                                 []
#
#                                                 nouns          verbs  \
# 0           [step, step, guide, share, market, india]       [invest]
# 1                               [story, koh, diamond]     [kohinoor]
# 2             [speed, internet, connection, use, vpn]     [increase]
# 3                                                  []        [solve]
# 4        [water, sugar, salt, methane, carbon, oxide]     [dissolve]
# 5              [astrology, sun, cap, moon, cap, rise]             []
# 6                                                  []          [buy]
# 7                                         [geologist]             []
# 8                                                 [シ]          [use]
# 9     [motorola, company, -PRON-, charter, motorolla]         [hack]
# 10        [method, separation, use, fresnel, biprism]         [find]
# 11                                 [youtube, comment]   [read, find]
# 12                                          [physics]        [learn]
# 13                                       [experience]             []
# 14  [law, change, status, student, visa, card, imm...      [compare]
# 15            [presidency, master, student, f1, visa]  [trump, mean]
# 16                                     [manipulation]         [mean]
# 17                        [girl, friend, guy, reject]         [want]
# 18                             [user, post, question]       [answer]
# 19                           [marketing, institution]     [banglore]
#
#                         adjs                                    Sub/Verb/Obj
# 0                         []                                              []
# 1                     [noor]                                              []
# 2                         []                    [((i), (increase), (speed))]
# 3                   [lonely]                          [((i), (solve), (it))]
# 4                         []                                              []
# 5                [capricorn]  [((i), (am), (cap, moon)), ((i), (am), (cap))]
# 6                         []                         [((i), (buy), (tiago))]
# 7                     [good]                      [((i), (be), (geologist))]
# 8                         []      [((you), (use), (シ)), ((you), (use), (し))]
# 9                         []                      [((i), (hack), (dcx3400))]
# 10                    [slit]                                              []
# 11                        []                                              []
# 12                        []                                              []
# 13                  [sexual]                                              []
# 14                   [green]                                              []
# 15  [current, international]                                              []
# 16                        []                                              []
# 17                        []                   [((girls), (want), (to, be))]
# 18                        []                                              []
# 19           [good, digital]     [((which), (is), (marketing, institution))]

# %%
term = "internet"

fRows = nRows.copy()
fRows["found"] = nRows["nouns"].apply(lambda l: l.count(term))

indexNames = fRows[ fRows['found'] == 0 ].index
fRows.drop(indexNames , inplace=True)
fRows
# Out:
#                                                   text  \
# 2    how can i increase the speed of my internet co...
# 78          how can i make money through the internet?
# 470  my new xbox one s can't connect to internet du...
# 720  hypothetical scenario: our actual credit card ...
# 730  is there a different price over the internet t...
#
#                                            noun chunks  \
# 2              [speed -PRON- internet connection, vpn]
# 78                                    [money internet]
# 470               [new xbox, internet setup, solution]
# 720  [hypothetical scenario, actual credit card sys...
# 730  [different price internet person, book room me...
#
#                                                  nouns               verbs  \
# 2              [speed, internet, connection, use, vpn]          [increase]
# 78                                   [money, internet]                  []
# 470                  [xbox, internet, setup, solution]           [connect]
# 720  [scenario, credit, card, system, banking, curr...  [exist, implement]
# 730  [price, internet, person, book, room, mexico, ...               [try]
#
#                                 adjs                        Sub/Verb/Obj  \
# 2                                 []        [((i), (increase), (speed))]
# 78                                []            [((i), (make), (money))]
# 470                            [new]                                  []
# 720  [hypothetical, actual, digital]  [((you), (implement), (currency))]
# 730                      [different]                                  []
#
#      found
# 2        1
# 78       1
# 470      1
# 720      1
# 730      1
