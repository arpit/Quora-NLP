# %% [markdown]
# # Structured data from Forums
#
# We are looking to investigate if Forum conversations can be used to extract structured data for XA

# %%
import pandas as pd
import numpy as np
import spacy
import en_core_web_sm
import textacy
import nltk

from spacy.lang.en.stop_words import STOP_WORDS
from nltk.stem.porter import *

nlp = en_core_web_sm.load()

# %%
rows = pd.read_csv("data/quora.csv", usecols=[0])

# %%
rows.head(4)
# Out:
#                                                 Link
# 0  After high winds, the wire from the street pol...
# 1         Error code when trying to update equipment
# 2                                         More speed
# 3            i need faster internet but cant get it.

# %%
stemmer = PorterStemmer()

def recognizePOS(parsed, POS) :
    words = []
    for token in parsed :
        if token.pos_ == POS :
            word = token.orth_
            words.append(word)
    return words


def extractEntities(text):   
    text = text.lower()
    
    doc = nlp(text)
    
    token_list = []
    for token in doc:
        token_list.append(token.lemma_)
        
    filtered_sentence =[] 

    for word in token_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False:
            filtered_sentence.append(word) 

    
    svos = textacy.extract.subject_verb_object_triples(doc)
    doc = nlp(" ".join(filtered_sentence))
    return pd.Series(data=[text, [chunk.text for chunk in doc.noun_chunks], 
                           recognizePOS(doc, "NOUN"),
                           recognizePOS(doc, "VERB"),
                           recognizePOS(doc, "ADJ"),
                           [svo for svo in svos]
                           ]
                    )

# %%
nRows = rows.apply(lambda row : extractEntities(row["Link"]),axis=1)

# %%
nRows = nRows.rename(columns={0: "text", 1: "noun chunks", 2: "nouns", 3: "verbs", 4: "adjs", 5: "Sub/Verb/Obj"})
nRows.head(60)
# Out:
#                                                  text  \
# 0   after high winds, the wire from the street pol...
# 1          error code when trying to update equipment
# 2                                          more speed
# 3             i need faster internet but cant get it.
# 4                                             payment
# 5         recently updated plan turned into nightmare
# 6                                                 xb7
# 7                                     property damage
# 8                        incompetent customer service
# 9   manage my plan link has been broke for several...
# 10                                  cable line repair
# 11                                        orange cord
# 12    comcast construction department contact request
# 13                             where are my xfi pods?
# 14        cable drop and conduit cable needs repaired
# 15                 xfi not available in my area, help
# 16                         coverage area in forest va
# 17            ordered xb7 new gateway and got old xb6
# 18                            never received flex box
# 19                                     address update
# 20                       online support doesn't work?
# 21  unable to changed scheduled date for automatic...
# 22  looking to cancel cable, but keep internet ser...
# 23      want specifics on 30-day money-back guarantee
# 24                             expired visa gift card
# 25                late fee due to expired credit card
# 26  my service and contract were changed without m...
# 27                               tress on cable lines
# 28  working from home and second ip address needed...
# 29                            change of internet plan
# 30                                tv box has no power
# 31                                      wifi 6 router
# 32           why can't you stand behind your product?
# 33  can't register mobile number and not getting a...
# 34                               extreme pro internet
# 35                                unwanted equipment.
# 36                        neighborhood serviceability
# 37  box not working right - can't get a human on t...
# 38                          low hanging wires in yard
# 39  why are  you performing work on the internet i...
# 40                                           pedestal
# 41                there is an orange cable in my yard
# 42                  nhl center ice and sports on hold
# 43      “you no longer have service at this location”
# 44                      removal of cable line to home
# 45                         xfinity insights community
# 46                                       modem router
# 47                          suddenly inactive account
# 48  current status for sayreville nj. when they ar...
# 49        deprovisioning all devices under my account
# 50                                 internet line drop
# 51  customer service expectations, message for tom...
# 52                         trying to pay my bill???!!
# 53             are live customer service reps working
# 54  old xfinity account preventing use of apps at ...
# 55                               cancel my service...
# 56                         how to delete old account?
# 57                                      cannot afford
# 58  renew the contract, any one can help? 4/20/202...
# 59  harrasment from automated chat and forced equi...
#
#                                           noun chunks  \
# 0                       [high wind, wire street pole]
# 1                      [error code, update equipment]
# 2                                             [speed]
# 3                                     [fast internet]
# 4                                           [payment]
# 5                   [recently update plan, nightmare]
# 6                                               [xb7]
# 7                                   [property damage]
# 8                      [incompetent customer service]
# 9                                             [break]
# 10                                [cable line repair]
# 11                                      [orange cord]
# 12  [comcast construction department contact request]
# 13                                  [-PRON- xfi, pod]
# 14                 [cable drop conduit cable, repair]
# 15                       [xfi, available -PRON- area]
# 16                          [coverage area forest va]
# 17                                                 []
# 18                                         [flex box]
# 19                                   [address update]
# 20                                   [online support]
# 21    [unable change schedule date automatic payment]
# 22                          [cable, internet service]
# 23                [specific 30-day money - guarantee]
# 24                                   [visa gift card]
# 25                                         [late fee]
# 26              [service contract, -PRON- permission]
# 27                                 [tress cable line]
# 28                        [second ip address, sb8200]
# 29                                    [internet plan]
# 30                                     [tv box power]
# 31                                    [wifi 6 router]
# 32                      [-PRON- stand -PRON- product]
# 33                            [mobile number, -PRON-]
# 34                             [extreme pro internet]
# 35                               [unwanted equipment]
# 36                      [neighborhood serviceability]
# 37                     [box work right - human phone]
# 38                            [low hanging wire yard]
# 39               [work internet neighbor school hour]
# 40                                                 []
# 41                         [orange cable -PRON- yard]
# 42                        [nhl center ice sport hold]
# 43                 [" -PRON- longer service location]
# 44                                                 []
# 45                        [xfinity insight community]
# 46                                     [modem router]
# 47                        [suddenly inactive account]
# 48              [current status, xfinity -PRON- town]
# 49                [deprovision device -PRON- account]
# 50                               [internet line drop]
# 51  [customer service expectation, message tom kar...
# 52                                  [pay -PRON- bill]
# 53                   [live customer service rep work]
# 54     [old xfinity account prevent, app new address]
# 55                                   [-PRON- service]
# 56                               [delete old account]
# 57                                                 []
# 58                                   [renew contract]
# 59         [harrasment automate chat force equipment]
#
#                                                 nouns            verbs  \
# 0                          [wind, wire, street, pole]               []
# 1                    [error, code, update, equipment]            [try]
# 2                                             [speed]               []
# 3                                          [internet]           [need]
# 4                                           [payment]               []
# 5                           [update, plan, nightmare]           [turn]
# 6                                                  []               []
# 7                                  [property, damage]               []
# 8                                 [customer, service]               []
# 9                         [-PRON-, plan, break, year]   [manage, link]
# 10                              [cable, line, repair]               []
# 11                                             [cord]               []
# 12       [construction, department, contact, request]               []
# 13                                         [xfi, pod]               []
# 14        [cable, drop, conduit, cable, need, repair]               []
# 15                                  [xfi, area, help]               []
# 16                       [coverage, area, forest, va]               []
# 17                                   [order, gateway]            [xb7]
# 18                                        [flex, box]        [receive]
# 19                                  [address, update]               []
# 20                                    [support, work]               []
# 21                  [change, schedule, date, payment]               []
# 22                 [cancel, cable, internet, service]           [look]
# 23                                 [money, guarantee]           [want]
# 24                                 [visa, gift, card]         [expire]
# 25                        [fee, expire, credit, card]               []
# 26            [service, contract, change, permission]            [pay]
# 27                                      [cable, line]          [tress]
# 28                        [home, ip, address, sb8200]     [work, need]
# 29                                   [internet, plan]         [change]
# 30                                   [tv, box, power]               []
# 31                                           [router]           [wifi]
# 32                                          [product]          [stand]
# 33                             [number, -PRON-, bill]  [register, add]
# 34                                         [internet]               []
# 35                                        [equipment]               []
# 36                     [neighborhood, serviceability]               []
# 37                          [box, work, human, phone]               []
# 38                              [hanging, wire, yard]               []
# 39           [work, internet, neighbor, school, hour]        [perform]
# 40                                                 []               []
# 41                      [orange, cable, -PRON-, yard]               []
# 42                         [center, ice, sport, hold]               []
# 43                                [service, location]               []
# 44                             [removal, cable, line]               []
# 45                      [xfinity, insight, community]               []
# 46                                    [modem, router]               []
# 47                                          [account]               []
# 48                [status, sayreville, xfinity, town]          [bring]
# 49                     [deprovision, device, account]               []
# 50                             [internet, line, drop]               []
# 51  [customer, service, expectation, message, tom,...               []
# 52                                     [-PRON-, bill]       [try, pay]
# 53                     [customer, service, rep, work]               []
# 54     [xfinity, account, prevent, use, app, address]               []
# 55                                  [-PRON-, service]         [cancel]
# 56                                          [account]               []
# 57                                                 []         [afford]
# 58                                   [contract, help]  [renew, expire]
# 59               [harrasment, chat, force, equipment]               []
#
#                    adjs                           Sub/Verb/Obj
# 0           [high, low]                                     []
# 1                    []                                     []
# 2                    []                                     []
# 3                [fast]            [((i), (need), (internet))]
# 4                    []                                     []
# 5                    []                                     []
# 6                    []                                     []
# 7                    []                                     []
# 8         [incompetent]                                     []
# 9                    []                                     []
# 10                   []                                     []
# 11             [orange]                                     []
# 12            [comcast]                                     []
# 13                   []                                     []
# 14                   []                                     []
# 15          [available]                                     []
# 16                   []                                     []
# 17           [new, old]                                     []
# 18                   []                                     []
# 19                   []                                     []
# 20             [online]                                     []
# 21  [unable, automatic]                                     []
# 22                   []                                     []
# 23           [specific]                                     []
# 24                   []                                     []
# 25               [late]                                     []
# 26             [double]                                     []
# 27                   []                                     []
# 28             [second]                                     []
# 29                   []                                     []
# 30                   []          [((tv, box), (has), (power))]
# 31                   []                                     []
# 32             [-PRON-]                                     []
# 33             [mobile]                                     []
# 34       [extreme, pro]                                     []
# 35           [unwanted]                                     []
# 36                   []                                     []
# 37              [right]     [((box), (ca, n't, get), (human))]
# 38                [low]                                     []
# 39                   []        [((you), (performing), (work))]
# 40           [pedestal]                                     []
# 41                   []             [((there), (is), (cable))]
# 42                [nhl]                                     []
# 43             [longer]           [((you), (have), (service))]
# 44                   []                                     []
# 45                   []                                     []
# 46                   []                                     []
# 47           [inactive]                                     []
# 48            [current]  [((they), (are, going), (to, bring))]
# 49                   []                                     []
# 50                   []                                     []
# 51                   []                                     []
# 52                   []                                     []
# 53               [live]                                     []
# 54           [old, new]                                     []
# 55                   []                                     []
# 56        [delete, old]                                     []
# 57                   []                                     []
# 58                   []                                     []
# 59           [automate]                                     []

# %%
term = "account"

fRows = nRows.copy()
fRows["found"] = nRows["nouns"].apply(lambda l: l.count(term))

indexNames = fRows[ fRows['found'] == 0 ].index
fRows.drop(indexNames , inplace=True)
fRows
# Out:
#                                                   text  \
# 47                           suddenly inactive account
# 49         deprovisioning all devices under my account
# 54   old xfinity account preventing use of apps at ...
# 56                          how to delete old account?
# 125      need bills of my old account ending with 9719
# 156                    remove old address from account
# 184             no order information or account set up
# 193                                 unlinking accounts
# 212          my account suddenly became "inactive"....
# 232  xfinity keeps sending account-related messages...
# 249      cancel service due to death of account holder
#
#                                            noun chunks  \
# 47                         [suddenly inactive account]
# 49                 [deprovision device -PRON- account]
# 54      [old xfinity account prevent, app new address]
# 56                                [delete old account]
# 125                          [bill -PRON- old account]
# 156                              [old address account]
# 184                        [order information account]
# 193                                  [unlink, account]
# 212                          [         -PRON- account]
# 232  [xfinity, account - relate message restrict us...
# 249                     [service death account holder]
#
#                                                  nouns             verbs  \
# 47                                           [account]                []
# 49                      [deprovision, device, account]                []
# 54      [xfinity, account, prevent, use, app, address]                []
# 56                                           [account]                []
# 125                               [bill, account, end]            [need]
# 156                                 [address, account]          [remove]
# 184                 [order, information, account, set]                []
# 193                                  [unlink, account]                []
# 212                                          [account]       [reconnect]
# 232  [xfinity, account, relate, message, user, -PRO...  [send, restrict]
# 249                  [service, death, account, holder]          [cancel]
#
#               adjs                       Sub/Verb/Obj  found
# 47      [inactive]                                 []      1
# 49              []                                 []      1
# 54      [old, new]                                 []      1
# 56   [delete, old]                                 []      1
# 125          [old]                                 []      1
# 156          [old]                                 []      1
# 184             []                                 []      1
# 193             []                                 []      1
# 212     [inactive]                                 []      1
# 232             []  [((xfinity), (keeps), (sending))]      2
# 249             []                                 []      1
