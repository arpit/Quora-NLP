# %% [markdown]
# # Structured data from Forums
#
# We are looking to investigate if Forum conversations can be used to extract structured data for XA

# %%
import pandas as pd
import numpy as np
import spacy
import en_core_web_sm
import textacy
import nltk

from spacy.lang.en.stop_words import STOP_WORDS
from nltk.stem.porter import *

nlp = en_core_web_sm.load()

# %%
rows = pd.read_csv("data/forum_data.csv", usecols=[0])

# %%
rows.head(4)
# Out:
#                                                 Link
# 0  After high winds, the wire from the street pol...
# 1         Error code when trying to update equipment
# 2                                         More speed
# 3            i need faster internet but cant get it.

# %%
stemmer = PorterStemmer()

def recognizePOS(parsed, POS) :
    words = []
    for token in parsed :
        if token.pos_ == POS :
            word = token.orth_
            words.append(word)
    return words


def extractEntities(text):   
    text = text.lower()
    
    doc = nlp(text)
    
    token_list = []
    for token in doc:
        token_list.append(token.text)
        
    filtered_sentence =[] 

    for word in token_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False:
            filtered_sentence.append(word.lemma_) 

    
    svos = textacy.extract.subject_verb_object_triples(doc)
    doc = nlp(" ".join(filtered_sentence))
    return pd.Series(data=[text, [chunk.text for chunk in doc.noun_chunks], 
                           recognizePOS(doc, "NOUN"),
                           recognizePOS(doc, "VERB"),
                           recognizePOS(doc, "ADJ"),
                           [svo for svo in svos],
                           filtered_sentence
                           ]
                    )

# %%
nRows = rows.apply(lambda row : extractEntities(row["Link"]),axis=1)

# %%
nRows = nRows.rename(columns={0: "text", 1: "noun chunks", 2: "nouns", 3: "verbs", 4: "adjs"})
nRows.head(60)
# Out:
#                                                  text  \
# 0   after high winds, the wire from the street pol...
# 1          error code when trying to update equipment
# 2                                          more speed
# 3             i need faster internet but cant get it.
# 4                                             payment
# 5         recently updated plan turned into nightmare
# 6                                                 xb7
# 7                                     property damage
# 8                        incompetent customer service
# 9   manage my plan link has been broke for several...
# 10                                  cable line repair
# 11                                        orange cord
# 12    comcast construction department contact request
# 13                             where are my xfi pods?
# 14        cable drop and conduit cable needs repaired
# 15                 xfi not available in my area, help
# 16                         coverage area in forest va
# 17            ordered xb7 new gateway and got old xb6
# 18                            never received flex box
# 19                                     address update
# 20                       online support doesn't work?
# 21  unable to changed scheduled date for automatic...
# 22  looking to cancel cable, but keep internet ser...
# 23      want specifics on 30-day money-back guarantee
# 24                             expired visa gift card
# 25                late fee due to expired credit card
# 26  my service and contract were changed without m...
# 27                               tress on cable lines
# 28  working from home and second ip address needed...
# 29                            change of internet plan
# 30                                tv box has no power
# 31                                      wifi 6 router
# 32           why can't you stand behind your product?
# 33  can't register mobile number and not getting a...
# 34                               extreme pro internet
# 35                                unwanted equipment.
# 36                        neighborhood serviceability
# 37  box not working right - can't get a human on t...
# 38                          low hanging wires in yard
# 39  why are  you performing work on the internet i...
# 40                                           pedestal
# 41                there is an orange cable in my yard
# 42                  nhl center ice and sports on hold
# 43      “you no longer have service at this location”
# 44                      removal of cable line to home
# 45                         xfinity insights community
# 46                                       modem router
# 47                          suddenly inactive account
# 48  current status for sayreville nj. when they ar...
# 49        deprovisioning all devices under my account
# 50                                 internet line drop
# 51  customer service expectations, message for tom...
# 52                         trying to pay my bill???!!
# 53             are live customer service reps working
# 54  old xfinity account preventing use of apps at ...
# 55                               cancel my service...
# 56                         how to delete old account?
# 57                                      cannot afford
# 58  renew the contract, any one can help? 4/20/202...
# 59  harrasment from automated chat and forced equi...
#
#                                        noun chunks  \
# 0                    [high wind, wire street pole]
# 1                         [error, tri updat equip]
# 2                                          [speed]
# 3                                [faster internet]
# 4                                        [payment]
# 5                              [recent updat plan]
# 6                                            [xb7]
# 7                                 [properti damag]
# 8                                [incompet custom]
# 9                                [manag plan link]
# 10                              [cabl line repair]
# 11                                    [orang cord]
# 12     [comcast construct, depart contact request]
# 13                                           [xfi]
# 14                [cabl drop conduit cabl, repair]
# 15                               [xfi, avail area]
# 16                        [coverag area forest va]
# 17                               [xb7 new gateway]
# 18                                      [flex box]
# 19                                 [address updat]
# 20                                 [onlin support]
# 21             [unabl chang schedul date, payment]
# 22                                          [cabl]
# 23                                              []
# 24                          [expir visa gift card]
# 25                    [late fee expir credit card]
# 26                         [servic contract chang]
# 27                               [tress cabl line]
# 28                     [second ip address, sb8200]
# 29                           [chang internet plan]
# 30                                  [tv box power]
# 31                                 [wifi 6 router]
# 32                                       [product]
# 33                   [regist mobil number, m bill]
# 34                              [extrem, internet]
# 35                                  [unwant equip]
# 36                                  [neighborhood]
# 37              [box work right - n't human phone]
# 38                            [low hang wire yard]
# 39            [work internet neighbor school hour]
# 40                                        [pedest]
# 41                                     [cabl yard]
# 42                     [nhl center ice sport hold]
# 43                                              []
# 44                                              []
# 45                        [xfiniti insight commun]
# 46                                  [modem router]
# 47                       [suddenli, inact account]
# 48          [current statu sayrevil, xfiniti town]
# 49                                 [devic account]
# 50                            [internet line drop]
# 51                  [custom servic, tom karinshak]
# 52                                  [tri pay bill]
# 53                   [live custom servic rep work]
# 54  [old xfiniti account prevent, app new address]
# 55                                        [servic]
# 56                             [delet old account]
# 57                                              []
# 58               [renew contract, 4/20/2020 expir]
# 59                                        [harras]
#
#                                         nouns               verbs  \
# 0                  [wind, wire, street, pole]                  []
# 1            [error, code, tri, updat, equip]                  []
# 2                                     [speed]                  []
# 3                                  [internet]              [need]
# 4                                   [payment]                  []
# 5                     [updat, plan, nightmar]              [turn]
# 6                                          []                  []
# 7                           [properti, damag]                  []
# 8                            [custom, servic]                  []
# 9                   [manag, plan, link, year]             [broke]
# 10                       [cabl, line, repair]                  []
# 11                                     [cord]                  []
# 12              [construct, contact, request]                  []
# 13                                 [xfi, pod]                  []
# 14  [cabl, drop, conduit, cabl, need, repair]                  []
# 15                   [xfi, avail, area, help]                  []
# 16                [coverag, area, forest, va]                  []
# 17                           [order, gateway]          [xb7, got]
# 18                                      [box]                  []
# 19                           [address, updat]                  []
# 20                           [onlin, support]              [work]
# 21   [unabl, schedul, date, automat, payment]                  []
# 22                   [cabl, internet, servic]      [look, cancel]
# 23                  [specif, money, guarante]              [want]
# 24                         [visa, gift, card]             [expir]
# 25                 [fee, expir, credit, card]                  []
# 26          [contract, chang, permiss, doubl]               [pay]
# 27                               [cabl, line]             [tress]
# 28                [home, ip, address, sb8200]        [work, need]
# 29                           [internet, plan]                  []
# 30                           [tv, box, power]                  []
# 31                                   [router]              [wifi]
# 32                                  [product]             [stand]
# 33                   [mobil, number, m, bill]  [regist, get, add]
# 34                         [extrem, internet]                  []
# 35                                    [equip]                  []
# 36                     [neighborhood, servic]                  []
# 37                  [box, work, right, phone]                  []
# 38                               [wire, yard]              [hang]
# 39   [work, internet, neighbor, school, hour]           [perform]
# 40                                   [pedest]                  []
# 41                               [cabl, yard]                  []
# 42                 [center, ice, sport, hold]                  []
# 43                                         []             [locat]
# 44                               [cabl, line]             [remov]
# 45                          [insight, commun]                  []
# 46                            [modem, router]                  []
# 47                 [suddenli, inact, account]                  []
# 48                           [sayrevil, town]  [statu, go, bring]
# 49                           [devic, account]                  []
# 50                     [internet, line, drop]                  []
# 51           [custom, servic, tom, karinshak]            [expect]
# 52                           [tri, pay, bill]                  []
# 53                [custom, servic, rep, work]              [live]
# 54      [account, prevent, use, app, address]                  []
# 55                                   [servic]            [cancel]
# 56                                  [account]             [delet]
# 57                                         []            [afford]
# 58                    [contract, help, expir]             [renew]
# 59                [harras, autom, chat, forc]                  []
#
#                    adjs                                      5  \
# 0           [high, low]                                     []
# 1                    []                                     []
# 2                    []                                     []
# 3              [faster]            [((i), (need), (internet))]
# 4                    []                                     []
# 5              [recent]                                     []
# 6                    []                                     []
# 7                    []                                     []
# 8            [incompet]                                     []
# 9                    []                                     []
# 10                   []                                     []
# 11              [orang]                                     []
# 12    [comcast, depart]                                     []
# 13                   []                                     []
# 14                   []                                     []
# 15                   []                                     []
# 16                   []                                     []
# 17           [new, old]                                     []
# 18       [receiv, flex]                                     []
# 19                   []                                     []
# 20                   []                                     []
# 21                   []                                     []
# 22                   []                                     []
# 23                   []                                     []
# 24                   []                                     []
# 25               [late]                                     []
# 26             [servic]                                     []
# 27                   []                                     []
# 28             [second]                                     []
# 29                   []                                     []
# 30                   []          [((tv, box), (has), (power))]
# 31                   []                                     []
# 32                   []                                     []
# 33                   []                                     []
# 34                [pro]                                     []
# 35             [unwant]                                     []
# 36                   []                                     []
# 37              [human]     [((box), (ca, n't, get), (human))]
# 38                [low]                                     []
# 39                   []        [((you), (performing), (work))]
# 40                   []                                     []
# 41                   []             [((there), (is), (cable))]
# 42                [nhl]                                     []
# 43                   []           [((you), (have), (service))]
# 44                   []                                     []
# 45            [xfiniti]                                     []
# 46                   []                                     []
# 47                   []                                     []
# 48   [current, xfiniti]  [((they), (are, going), (to, bring))]
# 49                   []                                     []
# 50                   []                                     []
# 51             [messag]                                     []
# 52                   []                                     []
# 53                   []                                     []
# 54  [old, xfiniti, new]                                     []
# 55                   []                                     []
# 56                [old]                                     []
# 57                   []                                     []
# 58                   []                                     []
# 59              [equip]                                     []
#
#                                                     6
# 0            [high, wind, ,, wire, street, pole, low]
# 1                    [error, code, tri, updat, equip]
# 2                                             [speed]
# 3                     [need, faster, internet, nt, .]
# 4                                           [payment]
# 5               [recent, updat, plan, turn, nightmar]
# 6                                               [xb7]
# 7                                   [properti, damag]
# 8                          [incompet, custom, servic]
# 9                    [manag, plan, link, broke, year]
# 10                               [cabl, line, repair]
# 11                                      [orang, cord]
# 12     [comcast, construct, depart, contact, request]
# 13                                      [xfi, pod, ?]
# 14          [cabl, drop, conduit, cabl, need, repair]
# 15                        [xfi, avail, area, ,, help]
# 16                        [coverag, area, forest, va]
# 17          [order, xb7, new, gateway, got, old, xb6]
# 18                                [receiv, flex, box]
# 19                                   [address, updat]
# 20                     [onlin, support, n't, work, ?]
# 21    [unabl, chang, schedul, date, automat, payment]
# 22          [look, cancel, cabl, ,, internet, servic]
# 23         [want, specif, 30-day, money, -, guarante]
# 24                          [expir, visa, gift, card]
# 25                   [late, fee, expir, credit, card]
# 26  [servic, contract, chang, permiss, ,, pay, dou...
# 27                                [tress, cabl, line]
# 28    [work, home, second, ip, address, need, sb8200]
# 29                            [chang, internet, plan]
# 30                                   [tv, box, power]
# 31                                  [wifi, 6, router]
# 32                           [n't, stand, product, ?]
# 33  [n't, regist, mobil, number, get, add, -, 'm, ...
# 34                            [extrem, pro, internet]
# 35                                 [unwant, equip, .]
# 36                             [neighborhood, servic]
# 37  [box, work, right, -, n't, human, phone, !, !,...
# 38                            [low, hang, wire, yard]
# 39  [ , perform, work, internet, neighbor, school,...
# 40                                           [pedest]
# 41                                [orang, cabl, yard]
# 42                    [nhl, center, ice, sport, hold]
# 43                      [“, longer, servic, locat, ”]
# 44                          [remov, cabl, line, home]
# 45                         [xfiniti, insight, commun]
# 46                                    [modem, router]
# 47                         [suddenli, inact, account]
# 48  [current, statu, sayrevil, nj, ., go, bring, x...
# 49                         [deprovis, devic, account]
# 50                             [internet, line, drop]
# 51  [custom, servic, expect, ,, messag, tom, karin...
# 52                    [tri, pay, bill, ?, ?, ?, !, !]
# 53                  [live, custom, servic, rep, work]
# 54  [old, xfiniti, account, prevent, use, app, new...
# 55                              [cancel, servic, ...]
# 56                           [delet, old, account, ?]
# 57                                           [afford]
# 58    [renew, contract, ,, help, ?, 4/20/2020, expir]
# 59                 [harras, autom, chat, forc, equip]

# %%
term = "account"

fRows = nRows.copy()
fRows["found"] = nRows["nouns"].apply(lambda l: l.count(term))

indexNames = fRows[ fRows['found'] == 0 ].index
fRows.drop(indexNames , inplace=True)
fRows
# Out:
#                                                   text  \
# 47                           suddenly inactive account
# 49         deprovisioning all devices under my account
# 54   old xfinity account preventing use of apps at ...
# 56                          how to delete old account?
# 125      need bills of my old account ending with 9719
# 156                    remove old address from account
# 184             no order information or account set up
# 232  xfinity keeps sending account-related messages...
# 249      cancel service due to death of account holder
#
#                                       noun chunks  \
# 47                    [suddenly inactive account]
# 49                                      [devices]
# 54        [old xfinity account, use, new address]
# 56                           [delete old account]
# 125                     [need, bills old account]
# 156                         [old address account]
# 184                   [order information account]
# 232  [xfinity, account - related messages, users]
# 249                [service death account holder]
#
#                                       nouns  \
# 47                                [account]
# 49                       [devices, account]
# 54   [xfinity, account, use, apps, address]
# 56                                [account]
# 125          [need, bills, account, ending]
# 156                      [address, account]
# 184      [order, information, account, set]
# 232     [xfinity, account, messages, users]
# 249       [service, death, account, holder]
#
#                                               verbs           adjs  \
# 47                                               []     [inactive]
# 49                                 [deprovisioning]             []
# 54                                     [preventing]     [old, new]
# 56                                               []  [delete, old]
# 125                                              []          [old]
# 156                                        [remove]          [old]
# 184                                              []             []
# 232  [keeps, sending, related, restricted, account]             []
# 249                                        [cancel]             []
#
#                                      5  \
# 47                                  []
# 49                                  []
# 54                                  []
# 56                                  []
# 125                                 []
# 156                                 []
# 184                                 []
# 232  [((xfinity), (keeps), (sending))]
# 249                                 []
#
#                                                      6  found
# 47                       [suddenly, inactive, account]      1
# 49                  [deprovisioning, devices, account]      1
# 54   [old, xfinity, account, preventing, use, apps,...      1
# 56                           [delete, old, account, ?]      1
# 125          [need, bills, old, account, ending, 9719]      1
# 156                    [remove, old, address, account]      1
# 184                 [order, information, account, set]      1
# 232  [xfinity, keeps, sending, account, -, related,...      1
# 249          [cancel, service, death, account, holder]      1
